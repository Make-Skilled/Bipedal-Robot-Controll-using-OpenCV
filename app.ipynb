# %%
import pandas as pd
data = pd.read_csv('gestures.csv')
data.head()
# Out:
#    0.5413358807563782   1.1301910877227783   7.097051479831862e-07  \
# 0            0.555595             1.116035            7.443810e-07
# 1            0.617983             1.065482            6.176654e-07
# 2            0.619818             1.021066            3.639126e-07
# 3            0.634180             0.982891            2.999235e-07
# 4            0.639236             0.967107            3.728006e-07
#
#     0.6098185181617737   1.1170105934143066   -0.04172676429152489  \
# 0             0.630643             1.085131              -0.043510
# 1             0.695902             1.002082              -0.008613
# 2             0.693052             0.981247              -0.009776
# 3             0.700425             0.958345              -0.016015
# 4             0.705457             0.946649              -0.015870
#
#     0.6621540784835815   1.0806114673614502   -0.07303570210933685  \
# 0             0.690587             1.025857              -0.071051
# 1             0.745000             0.919581              -0.003435
# 2             0.746395             0.908285              -0.007256
# 3             0.751620             0.898076              -0.016592
# 4             0.752068             0.884081              -0.015391
#
#     0.6817402243614197  ...   0.4309006333351135   0.8951941728591919  \
# 0             0.739238  ...             0.456514             0.831843
# 1             0.773702  ...             0.520063             0.714453
# 2             0.777338  ...             0.531187             0.706004
# 3             0.779172  ...             0.567841             0.693638
# 4             0.779483  ...             0.570945             0.687983
#
#     -0.13168242573738098   0.40880775451660156   0.8332204222679138  \
# 0              -0.120535              0.433453             0.767158
# 1               0.001381              0.499571             0.662125
# 2              -0.009086              0.511927             0.656295
# 3              -0.007597              0.552259             0.649489
# 4              -0.003361              0.557793             0.645759
#
#     -0.15126943588256836   0.3941737115383148   0.7787802815437317  \
# 0              -0.140727             0.416440             0.711191
# 1              -0.004639             0.484437             0.614450
# 2              -0.014907             0.497594             0.608926
# 3              -0.012168             0.539813             0.607924
# 4              -0.008315             0.547292             0.608126
#
#     -0.16338373720645905  Open Hand
# 0              -0.152044  Open Hand
# 1              -0.007965  Open Hand
# 2              -0.019459  Open Hand
# 3              -0.015428  Open Hand
# 4              -0.011959  Open Hand
#
# [5 rows x 64 columns]

# %%
X = data.iloc[:,:-1].values
X
# Out:
# array([[ 5.55595219e-01,  1.11603475e+00,  7.44380998e-07, ...,
#          4.16440010e-01,  7.11190999e-01, -1.52043641e-01],
#        [ 6.17983043e-01,  1.06548154e+00,  6.17665364e-07, ...,
#          4.84437257e-01,  6.14449501e-01, -7.96525367e-03],
#        [ 6.19817555e-01,  1.02106619e+00,  3.63912562e-07, ...,
#          4.97594386e-01,  6.08925879e-01, -1.94591321e-02],
#        ...,
#        [ 1.83820069e-01,  8.70134711e-01,  4.38421353e-08, ...,
#          6.89188689e-02,  2.95764178e-01, -8.95683765e-02],
#        [ 1.75471857e-01,  8.76245320e-01,  7.27496570e-08, ...,
#          6.30969405e-02,  2.98620492e-01, -1.00049689e-01],
#        [ 1.70923918e-01,  8.86443496e-01, -3.29542118e-08, ...,
#          5.58569878e-02,  2.97970712e-01, -8.47938210e-02]])

# %%
Y = data.iloc[:,-1].values
Y
# Out:
# array(['Open Hand', 'Open Hand', 'Open Hand', ..., 'Hip Hop', 'Hip Hop',
#        'Hip Hop'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
X_train.shape
# Out:
# (2746, 63)

# %%
X_test.shape

Y_train.shape

Y_test.shape

from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 3)

model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
import sklearn
sklearn.metrics.accuracy_score(Y_test, model.predict(X_test))
# Out:
# 0.9985443959243085

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
